# %%
#import packages
import numpy as np
import rasterio
from rasterio.merge import merge
from rasterio.plot import show
import glob
import os

# %%
#set working directory
working_dir = os.chdir('/home/naheemadebisi/snow-analytics/lidar/raster/Digital_Surface_Models')

# %%
#list all directories in a directory using glob
dirs = glob.glob('*[0 -9]')
dirs.sort()
dirs
# Out:
# ['hh_gm1_0001',
#  'hh_gm1_0002',
#  'hh_gm1_0003',
#  'hh_gm1_0004',
#  'hh_gm1_0005',
#  'hh_gm1_0006',
#  'hh_gm1_0007',
#  'hh_gm1_0008',
#  'hh_gm1_0009',
#  'hh_gm1_0010',
#  'hh_gm1_0011',
#  'hh_gm1_0012',
#  'hh_gm1_0013',
#  'hh_gm1_0014',
#  'hh_gm1_0015',
#  'hh_gm1_0016',
#  'hh_gm1_0017',
#  'hh_gm1_0018',
#  'hh_gm1_0019',
#  'hh_gm1_0020',
#  'hh_gm1_0021',
#  'hh_gm1_0022',
#  'hh_gm1_0023',
#  'hh_gm1_0024',
#  'hh_gm1_0025',
#  'hh_gm1_0026',
#  'hh_gm1_0027',
#  'hh_gm1_0028',
#  'hh_gm1_0029',
#  'hh_gm1_0030',
#  'hh_gm1_0031',
#  'hh_gm1_0032',
#  'hh_gm1_0033',
#  'hh_gm1_0034',
#  'hh_gm1_0035',
#  'hh_gm1_0036',
#  'hh_gm1_0037',
#  'hh_gm1_0038',
#  'hh_gm1_0039',
#  'hh_gm1_0040',
#  'hh_gm1_0041',
#  'hh_gm1_0042',
#  'hh_gm1_0043',
#  'hh_gm1_0044',
#  'hh_gm1_0045',
#  'hh_gm1_0046',
#  'hh_gm1_0047',
#  'hh_gm1_0048',
#  'hh_gm1_0049',
#  'hh_gm1_0050',
#  'hh_gm1_0051',
#  'hh_gm1_0052',
#  'hh_gm1_0053',
#  'hh_gm1_0054',
#  'hh_gm1_0055',
# ...

# %%
len(dirs)
# Out:
# 623

# %%
dir_missing = []
#check if a file is in directory
for dir in dirs:
    if 'w001001.adf' not in os.listdir(dir):
        dir_missing.append(dir)

dir_missing

#save list as a text file
with open('dsm_missing.txt', 'w') as f:
    for item in dir_missing:
        f.write("%s\n" % item)


# os.path.isfile('/home/naheemadebisi/snow-analytics/lidar/raster/Bare_Earth_Digital_Elevation_Models/w001001.adf')
