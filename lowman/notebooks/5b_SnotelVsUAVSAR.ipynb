# %% [markdown]
# In this notebook, I modified 5_SnotelVsUAVSAR notebook with result from 4b_SnowDepth-TimeSeries

# %%
#import packages
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
#print working directory
print(os.getcwd())
# Out:
# /home/naheemadebisi/snow-analytics/lowman

# %%
#read the cvs file
snowtel_SD = pd.read_csv('637_25_WATERYEAR=2021.csv', skiprows=3, index_col= ['Date'], usecols= ['Date', 'SNWD.I-1 (in) '], na_values = -99.9)
snowtel_SD
# Out:
#             SNWD.I-1 (in)
# Date
# 2020-10-01             0.0
# 2020-10-02             0.0
# 2020-10-03             0.0
# 2020-10-04             0.0
# 2020-10-05             0.0
# ...                    ...
# 2021-09-27             0.0
# 2021-09-28             0.0
# 2021-09-29             0.0
# 2021-09-30             0.0
# 2021-09-30             NaN
#
# [366 rows x 1 columns]

# %%
#Set to datetime format
snowtel_SD.index = pd.to_datetime(snowtel_SD.index)
snowtel_SD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 366 entries, 2020-10-01 to 2021-09-30
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SNWD.I-1 (in)   365 non-null    float64
# dtypes: float64(1)
# memory usage: 5.7 KB

# %%
#change the unit of the SD values to centimeter
snowtel_SD['SD (cm)'] = snowtel_SD['SNWD.I-1 (in) '] * 2.54
snowtel_SD
# Out:
#             SNWD.I-1 (in)   SD (cm)
# Date
# 2020-10-01             0.0      0.0
# 2020-10-02             0.0      0.0
# 2020-10-03             0.0      0.0
# 2020-10-04             0.0      0.0
# 2020-10-05             0.0      0.0
# ...                    ...      ...
# 2021-09-27             0.0      0.0
# 2021-09-28             0.0      0.0
# 2021-09-29             0.0      0.0
# 2021-09-30             0.0      0.0
# 2021-09-30             NaN      NaN
#
# [366 rows x 2 columns]

# %%
snowtel_SD = snowtel_SD.loc['2021-01-01':'2021-04-30']

# %%
#create a column of difference between current and previous snow depth
snowtel_SD['diff_SWE'] = snowtel_SD['SD (cm)'].diff()
snowtel_SD
# Out:
# /tmp/ipykernel_109666/2788045148.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   snowtel_SD['diff_SWE'] = snowtel_SD['SD (cm)'].diff()
#             SNWD.I-1 (in)   SD (cm)  diff_SWE
# Date
# 2021-01-01            46.0   116.84       NaN
# 2021-01-02            44.0   111.76     -5.08
# 2021-01-03            45.0   114.30      2.54
# 2021-01-04            54.0   137.16     22.86
# 2021-01-05            58.0   147.32     10.16
# ...                    ...      ...       ...
# 2021-04-26            31.0    78.74      7.62
# 2021-04-27            30.0    76.20     -2.54
# 2021-04-28            29.0    73.66     -2.54
# 2021-04-29            27.0    68.58     -5.08
# 2021-04-30            25.0    63.50     -5.08
#
# [120 rows x 3 columns]

# %%
# Set font size and font family
plt.rcParams.update({'font.size': 18})
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

#create a figure and axes elements
fig, ax = plt.subplots(figsize=(13,9), constrained_layout=True)

snowtel_SD.plot(ax=ax, y='SD (cm)', color='blue', linewidth=2, label='Snow Depth')

ax.set_ylabel('Snow Depth (cm)')
ax.set_xlabel('Date')
ax.legend(loc='upper left')


plt.show()

# #save the figure
# fig.savefig('Monthly_Mean_SWE.jpeg', dpi=500)

# %%
#The interferogram starts at 01-15-2021; let's take the snotel depth at the date as the base value
snotel_base = snowtel_SD.loc['2021-01-15']
snotel_base
# Out:
# SNWD.I-1 (in)      60.00
# SD (cm)           152.40
# diff_SWE           -2.54
# Name: 2021-01-15 00:00:00, dtype: float64

# %%
#Create a dataframe of start and end dates for each interferograms

int_dates = [[1, '01-01-2021', '01-15-2021', 152.04, 152.04],
            [2, '01-15-2021', '01-20-2021', -20.82343, -2.921242], 
            [3, '01-20-2021', '01-27-2021', -30.762129, 3.670603], 
            [4, '01-27-2021', '02-03-2021', 3.46591, 9.663062], # no data
            [5, '02-03-2021', '02-10-2021', 0.270731, 4.9431534],
            [6, '02-10-2021', '03-03-2021', 2.123164, 18.341123], # no uwp (-0.225704)
            [7, '03-03-2021', '03-10-2021', -9.52903, 0.920546],
            [8, '03-10-2021', '03-16-2021', 9.208427, 0.193312], 
            [9, '03-16-2021', '03-22-2021', 6.311231, -6.585196]]

uavsar_SD_df = pd.DataFrame(int_dates, columns= ['inteferograms', 'start_date', 'end_date', 'SnowDepth', 'SnowDepth_inc']).set_index('end_date')

#uavsar_SD_df

# %%
#set the index to datetime format
uavsar_SD_df.index = pd.to_datetime(uavsar_SD_df.index)

#Create a cumulative sum of the snow depth
uavsar_SD_df['cum_SD'] = uavsar_SD_df['SnowDepth'].cumsum()
uavsar_SD_df['cum_SD_inc'] = uavsar_SD_df['SnowDepth_inc'].cumsum()
uavsar_SD_df
# Out:
#             inteferograms  start_date   SnowDepth  SnowDepth_inc      cum_SD  \
# end_date
# 2021-01-15              1  01-01-2021  152.040000     152.040000  152.040000
# 2021-01-20              2  01-15-2021  -20.823430      -2.921242  131.216570
# 2021-01-27              3  01-20-2021  -30.762129       3.670603  100.454441
# 2021-02-03              4  01-27-2021    3.465910       9.663062  103.920351
# 2021-02-10              5  02-03-2021    0.270731       4.943153  104.191082
# 2021-03-03              6  02-10-2021    2.123164      18.341123  106.314246
# 2021-03-10              7  03-03-2021   -9.529030       0.920546   96.785216
# 2021-03-16              8  03-10-2021    9.208427       0.193312  105.993643
# 2021-03-22              9  03-16-2021    6.311231      -6.585196  112.304874
#
#             cum_SD_inc
# end_date
# 2021-01-15  152.040000
# 2021-01-20  149.118758
# 2021-01-27  152.789361
# 2021-02-03  162.452423
# 2021-02-10  167.395576
# 2021-03-03  185.736699
# 2021-03-10  186.657245
# 2021-03-16  186.850557
# 2021-03-22  180.265361

# %% [markdown]
# Lidar-Snow Depth at snotel site on the 15-03-2021 = 188.44cm

# %%
snowtel_SD.loc['2021-03-15']
# Out:
# SNWD.I-1 (in)      74.00
# SD (cm)           187.96
# diff_SWE           -2.54
# Name: 2021-03-15 00:00:00, dtype: float64

# %%
lidar_snow = ['2021-03-15', 188.44]

# %%
# Set font size and font family
plt.rcParams.update({'font.size': 18})
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

#create a figure and axes elements
fig, ax = plt.subplots(figsize=(13,9), constrained_layout=True)

#plot snowtel data and uavsar data
snowtel_SD.plot(ax=ax, y='SD (cm)', color='blue', linewidth=2, label='Snotel Snow Depth')
# uavsar_SD_df['cum_SD'].plot(ax=ax, color='red', linewidth=2, label='UAVSAR Snow Depth', marker='o')
uavsar_SD_df['cum_SD_inc'].plot(ax=ax, color='red', linewidth=2, label='UAVSAR Snow Depth', marker='o')

#plot a point value of the lidar snow depth on Mar-15-2021
plt.scatter(lidar_snow[0], lidar_snow[1], color='green', marker='*', label='lidar Snow Depth', s=200)

#change tick location
# ax.yaxis.set_major_locator(plt.MaxNLocator(13))
ax.yaxis.set_major_locator(plt.MultipleLocator(10))



ax.set_ylabel('Snow Depth (cm)')
ax.set_xlabel('Date')
ax.legend(loc='upper left')


plt.show()

# #save the figure
fig.savefig('UAVSAR-snotel-lidar.jpeg', dpi=500)
