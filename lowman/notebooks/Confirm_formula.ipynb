# %%
import numpy as np

# %%
unw_arr_whisker = 2
incidence_angle = 0.5
snowdepth_cm = (-1 * unw_arr_whisker * 24.0)/(4 * np.pi * (np.cos(incidence_angle)  - np.sqrt(1.5 - (np.sin(incidence_angle)**2))))
snowdepth_cm
# Out:
# 15.313957813082517

# %%
a = 4 *np.pi
b = np.cos(incidence_angle)
c = np.sqrt(1.5-np.sin(incidence_angle)**2)

# %%
-1*unw_arr_whisker*24/(a * (b - c))
# Out:
# 15.313957813082517

# %%
unw_arr_whisker/(-1*(a/24)*(b-c))
# Out:
# 15.31395781308252
